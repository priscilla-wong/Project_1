# %%
# Imports

import panel as pn
pn.extension('plotly')
import plotly.express as px
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import os
from pathlib import Path
from dotenv import load_dotenv
import numpy as np

# %%
# Data breakdown: Covid cases versus personal consumption by month
# Import covid case data

covid_path = Path("../Resources/covid_data.csv")
covid_data = pd.read_csv(covid_path)

#covid_data.set_index(pd.to_datetime(covid_data['submission_date'], infer_datetime_format=True), inplace=True)

covid_data.head()
# Out:
#    year month yearmonth  day state  tot_cases  conf_cases  prob_cases  \
# 0  2020   M01   2020M01   22    AK          0         NaN         NaN
# 1  2020   M01   2020M01   23    AK          0         NaN         NaN
# 2  2020   M01   2020M01   24    AK          0         NaN         NaN
# 3  2020   M01   2020M01   25    AK          0         NaN         NaN
# 4  2020   M01   2020M01   26    AK          0         NaN         NaN
#
#    new_case  pnew_case  tot_death  conf_death  prob_death  new_death  \
# 0         0        NaN          0         NaN         NaN          0
# 1         0        NaN          0         NaN         NaN          0
# 2         0        NaN          0         NaN         NaN          0
# 3         0        NaN          0         NaN         NaN          0
# 4         0        NaN          0         NaN         NaN          0
#
#    pnew_death       created_at consent_cases consent_deaths
# 0         NaN  3/26/2020 16:22           NaN            NaN
# ...

# %%
# Clean covid data by saving only date, state, total cases, and total deaths

#covid_data.set_index(pd.to_datetime(covid_data['submission_date'], infer_datetime_format=True), inplace=True)
covid_df = covid_data.drop(columns=["year", "month", "day", "conf_cases", "prob_cases", "pnew_case", "conf_death", "prob_death", "new_death", "pnew_death", "created_at", "consent_cases", "consent_deaths"])
covid_df.head()
# Out:
#   yearmonth state  tot_cases  new_case  tot_death
# 0   2020M01    AK          0         0          0
# 1   2020M01    AK          0         0          0
# 2   2020M01    AK          0         0          0
# 3   2020M01    AK          0         0          0
# 4   2020M01    AK          0         0          0

# %%
# Sort covid data by date and state

covid_df = covid_df.sort_values(by=['state', 'yearmonth'])
covid_df.head()
# Out:
#   yearmonth state  tot_cases  new_case  tot_death
# 0   2020M01    AK          0         0          0
# 1   2020M01    AK          0         0          0
# 2   2020M01    AK          0         0          0
# 3   2020M01    AK          0         0          0
# 4   2020M01    AK          0         0          0

# %%
# Group data

covid_df = covid_df.groupby('yearmonth')['new_case'].sum().plot(kind='bar', x='Month', y='Cases', title='Covid Cases from Jan 2020 to March 2021')
covid_df

# %%
# Import personal consumption data
# This was manually cleaned in excel - need to figure out how to clean via python only
# Took the 7th tab "U20305-M" and deleted the top 7 lines

pc_path = Path("../Resources/pc_data.csv")
pc_data = pd.read_csv(pc_path)
pc_data.head(10)
# Out:
#   Line                                         Unnamed: 1 Unnamed: 2  1959M01  \
# 0  NaN  Personal consumption expenditures by major typ...        NaN      NaN
# 1    1            Personal consumption expenditures (PCE)     DPCERC  306,091
# 2    2                                              Goods     DGDSRC  167,411
# 3    3                                      Durable goods     DDURRC   42,295
# 4    4                           Motor vehicles and parts     DMOTRC   16,904
# 5    5        Furnishings and durable household equipment     DFDHRC   15,019
# 6    6                    Recreational goods and vehicles     DREQRC    6,258
# 7    7                                Other durable goods     DODGRC    4,114
# 8    8                                   Nondurable goods     DNDGRC  125,117
# 9    9      Food and beverages purchased for off-premi...     DFXARC   61,876
#
#    1959M02  1959M03  1959M04  1959M05  1959M06  1959M07  ...     2020M05  \
# ...

# %%
# Clean personal consumption data
# Keep columns 2019M12 through 2021M02
# Remove line NaNs, 

pc_df = pc_data.dropna()

# %%
pc_df.rename(columns={pc_df.columns[1]: "Category"}, inplace = True)
# Out:
# C:\Users\prisc\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
pc_df = pc_df.drop(columns=pc_df.columns[0]).copy()

# %%
pc_df = pc_df.drop(columns=pc_df.columns[1]).copy()

# %%
pc_df.reset_index()
# Out:
#     index                                           Category  1959M01  \
# 0       1            Personal consumption expenditures (PCE)  306,091
# 1       2                                              Goods  167,411
# 2       3                                      Durable goods   42,295
# 3       4                           Motor vehicles and parts   16,904
# 4       5        Furnishings and durable household equipment   15,019
# 5       6                    Recreational goods and vehicles    6,258
# 6       7                                Other durable goods    4,114
# 7       8                                   Nondurable goods  125,117
# 8       9      Food and beverages purchased for off-premi...   61,876
# 9      10                              Clothing and footwear   24,379
# 10     11                    Gasoline and other energy goods   15,021
# 11     12                             Other nondurable goods   23,840
# ...

# %%
# Transposing data so dates are in the row position

pc_df = pc_df.transpose()

pc_df.head()
# Out:
#                                                    1        2   \
# Category      Personal consumption expenditures (PCE)    Goods
# 1959M01                                       306,091  167,411
# 1959M02                                       309,554  169,596
# 1959M03                                       312,702  172,162
# 1959M04                                       312,193  170,680
#
#                        3                             4   \
# Category    Durable goods      Motor vehicles and parts
# 1959M01            42,295                        16,904
# 1959M02            44,207                        18,467
# 1959M03            44,445                        18,900
# 1959M04            45,065                        19,436
#
#                                                        5   \
# Category      Furnishings and durable household equipment
# 1959M01                                            15,019
# 1959M02                                            15,286
# ...
